# %% [raw]
# import pickle
# import pandas as pd
# import numpy as np
# dataset = pd.read_csv("50_Startups.csv")
# dataset = pd.get_dummies(dataset,drop_first=True)
# dataset = dataset.astype(int)
# independent = dataset[['R&D Spend', 'Administration', 'Marketing Spend',
#        'State_Florida', 'State_New York']]
# dependent = dataset[['Profit']]

# %% [raw]
# from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test = train_test_split(independent, dependent, test_size = 0.30, random_state=0)

# %% [raw]
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# %% [raw]
# preinput = sc.transform([[85328,154135,144050,1,0]])

# %% [raw]
# loaded_model = pickle.load(open('Finalize_Model_RF.sav', 'rb'))

# %% [raw]
# result = loaded_model.predict(preinput)

# %% [raw]
# result

# %%
# Reduced Code by save and load standardscaler file here

# %%
import pickle
import pandas as pd
import numpy as np

# %%
sc = pickle.load(open("Scaler_RF.sav", 'rb'))
loaded_model = pickle.load(open('Finalize_Model_RF.sav', 'rb'))

# %%
preinput = sc.transform([[85328,154135,144050,1,0]])
# Out:
# C:\Users\gopi\Anaconda\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
result = loaded_model.predict(preinput)

# %%
result
# Out:
# array([118024.80624371])
