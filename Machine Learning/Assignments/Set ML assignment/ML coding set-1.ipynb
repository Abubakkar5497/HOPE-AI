# %%
#1.Answers
import pandas as pd

data = {'Customer_ID': [101, 102, 103, 101, 104, 102, 101, 105, 102, 103],
        'Purchase_Amount': [200, 150, 180, 220, 300, 200, 100, 400, 250, 300]}
df = pd.DataFrame(data)

purchase_amount = df.groupby('Customer_ID')['Purchase_Amount'].sum().reset_index(name='Top Purchase')
print(f'Total Purchases per Customer:\n{purchase_amount}')
top3_freq_customer = purchase_amount.sort_values(by='Top Purchase',ascending=False).head(3)
print(f'Top 3 Frequent Customers:\n{top3_freq_customer}')

# %%
#2.Answers
import pandas as pd
from sklearn.linear_model import LinearRegression

data = {'Square_Feet': [1500, 2000, 2500, 3000, 3500],
        'Price': [300000, 400000, 500000, 600000, 700000]}
df=pd.DataFrame(data)

X = df[['Square_Feet']]
y= df['Price']

model = LinearRegression()
model1 = model.fit(X,y)

pred =model1.predict([[1800], [2800]])
print(pred)

# %%
#3.Answers

import pandas as pd
data = {'Category': ['A', 'B', 'C', 'A', 'D', 'B', 'A', 'E', 'B', 'C', 'C', 'A'],
        'Value': [10, 15, 20, 30, 25, 18, 22, 40, 35, 50, 45, 15]}

df = pd.DataFrame(data)

total_count = df.groupby('Category')['Value'].size().reset_index(name='Count')
print(f'Total Occurrences per Category:\n{total_count}')

top3_cat = total_count.sort_values(by='Count',ascending = False).head(3)
print(f'Top 3 Frequent Categories:\n{top3_cat}')
# Out:
# Total Occurrences per Category:
#   Category  Count
# 0        A      4
# 1        B      3
# 2        C      3
# 3        D      1
# 4        E      1
# Top 3 Frequent Categories:
#   Category  Count
# 0        A      4
# 1        B      3
# 2        C      3

# %%
#4.Answers

import pandas as pd


data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Age': [25, 30, None, 35, None]}
df = pd.DataFrame(data)

print(f'Original Data:\n{df}')

mean_age = df['Age'].mean()
df['Age']=df['Age'].fillna(mean_age)

print(f'\nData after Imputation:\n{df}')
# Out:
# Original Data:
#       Name   Age
# 0    Alice  25.0
# 1      Bob  30.0
# 2  Charlie   NaN
# 3    David  35.0
# 4      Eve   NaN
#
# Data after Imputation:
#       Name   Age
# 0    Alice  25.0
# 1      Bob  30.0
# 2  Charlie  30.0
# 3    David  35.0
# 4      Eve  30.0

# %%
#5.Answers
import pandas as pd
from sklearn.linear_model import LinearRegression

data = {'Experience': [1, 2, 3, 4, 5], 
        'Salary': [30000, 35000, 40000, 45000, 50000]}
df = pd.DataFrame(data)
model = LinearRegression()
X= df[['Experience']]
y= df['Salary']
model1 = model.fit(X,y)

pred = model1.predict([[6]])
print(f'Predicted Salary for 6 years of experience: ${pred}')
# Out:
# Predicted Salary for 6 years of experience: $[55000.]

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
data = {'word_count': [100, 150, 200, 120, 180, 220], 
        'is_spam': ['ham', 'spam', 'spam', 'ham', 'spam', 'spam']}
df = pd.DataFrame(data)
le = LabelEncoder()
df['is_spam_encoded'] = le.fit_transform(df['is_spam'])
X=df[['word_count']]
y=df['is_spam_encoded']

model = LogisticRegression()
model = model.fit(X,y)
pred = model.predict([[200]])
result =le.inverse_transform(pred)

print(f'Prediction for email with 200 words: {result[0]}')
# Out:
# Prediction for email with 200 words: spam
# C:\Anaconda3\envs\aiml\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
