# %%
import pickle

# %%
loaded_model = pickle.load(open("Finalized_model_linear.sav", 'rb')) # for use saved model i have to use pickle.load
result = loaded_model.predict([[13]])
# Out:
# C:\Users\gopi\Anaconda\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[148460.78806172]])

# %%
result = loaded_model.predict([[0]])
# Out:
# C:\Users\gopi\Anaconda\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])

# %%
# Zero exp salary = 26777.3913412 actually it is equal to bias the orgin of the line bcz data start from 1.1 yr exp and bias is starting value
