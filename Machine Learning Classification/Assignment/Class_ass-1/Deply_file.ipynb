# %%
import pickle
load_model = pickle.load(open('Finilize_model_SVC.sav', 'rb'))
sc=pickle.load(open('Scaler_model.sav','rb'))
preinput= sc.transform([[2,	76,	3,0,148,57,3,137,4,12,0	,0,	0,	0,	0,	0,	1,	1,	0 ,1,0,0,1,0,1,0,0]])
result = load_model.predict(preinput)
print(result)
# Out:
# [1]
# C:\Users\gopi\Anaconda\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
