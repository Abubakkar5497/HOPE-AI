# %%
import pickle

# %%
load_model = pickle.load(open('Finalize_Model_RF.sav', 'rb'))
age = int(input('Enter age:'))
print(age)
salary = float(input('Enter salary:'))
print(salary)
sex_male = int(input('Enter sex_male:'))
print(sex_male)
result = load_model.predict([[age, salary, sex_male ]])
# Out:
# Enter age: 28
# 28
# Enter salary: 24000
# 24000.0
# Enter sex_male: 0
# 0
# C:\Users\gopi\Anaconda\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print(result)
# Out:
# [0]
