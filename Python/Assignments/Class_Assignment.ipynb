# %%
from Assignmentclass import SubfieldsInAI
from Assignmentclass import OddEven
from Assignment2 import FindPercent
from Assignment2 import EligibilityForMarriage
from Assignment3 import triangle

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
OddEven.OddEven()
# Out:
# Enter a Number:  52452
# 52452 is Even number

# %%
print("Your Gender: Male")
print("Your Age: 20")

EligibilityForMarriage.Eligible('Male', 20)
# Out:
# Your Gender: Male
# Your Age: 20
# NOT ELIGIBLE

# %%
FindPercent.percentage()
# Out:
# Subject1=  98
# Subject2=  87
# Subject3=  95
# Subject4=  95
# Subject5=  93
# Total :  468
# Percentage :  93.60000000000001

# %%
triangle.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10

# %%
BMIAdd.addition(5, 7)
# Out:
# 12

# %%
BMIAdd.BMI()
# Out:
# Enter the BMI Index:  26
# Overweight
# 'Overweight'
